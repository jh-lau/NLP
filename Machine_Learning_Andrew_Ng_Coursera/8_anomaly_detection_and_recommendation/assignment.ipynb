# %% [markdown]
# # Load modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


from scipy.io import loadmat
from scipy import stats

from sklearn.preprocessing import StandardScaler, scale

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
data = loadmat('data/ex8data1.mat')
X = data['X']
Xval = data['Xval']
yval = data['yval']
X.shape, Xval.shape, yval.shape
# Out:
# ((307, 2), (307, 2), (307, 1))

# %%
sns.scatterplot(X[:,0],X[:,1])
plt.show()

# %%
sns.jointplot(X[:,0], X[:,1], kind="kde", height=5, space=0)

# %%
sns.distplot(X[:,0])
plt.show()

# %%
sns.distplot(X[:,1])
plt.show()

# %%
scaler = StandardScaler()
scaler.fit(X)
scaler.mean_, scaler.scale_, scaler.var_
# Out:
# (array([14.11222578, 14.99771051]),
#  array([1.35374717, 1.3075723 ]),
#  array([1.83263141, 1.70974533]))

# %% [markdown]
# ## 根据平均值和方差确定正态分布形态

# %%
dist = stats.norm(scaler.mean_[0], scaler.var_[0])
dist.pdf(15)
# Out:
# 0.1935875044615038

# %%
dist.pdf(X[:,0])[:50]
# Out:
# array([0.183842  , 0.20221694, 0.21746136, 0.19778763, 0.20858956,
#        0.21652359, 0.16991291, 0.15123542, 0.1163989 , 0.1594734 ,
#        0.21716057, 0.21760472, 0.20141857, 0.20157497, 0.21711385,
#        0.21758775, 0.21695576, 0.2138258 , 0.21057069, 0.1173018 ,
#        0.20765108, 0.21717452, 0.19510663, 0.21702152, 0.17429399,
#        0.15413455, 0.21000109, 0.20223586, 0.21031898, 0.21313426,
#        0.16158946, 0.2170794 , 0.17825767, 0.17414633, 0.1264951 ,
#        0.19723662, 0.14538809, 0.21766361, 0.21191386, 0.21729442,
#        0.21238912, 0.18799417, 0.21259798, 0.21752767, 0.20616968,
#        0.21520366, 0.1280081 , 0.21768113, 0.21539967, 0.16913173])

# %%
p = np.zeros(X.shape)
p[:,0] = stats.norm(scaler.mean_[0], scaler.var_[0]).pdf(X[:,0])
p[:,1] = stats.norm(scaler.mean_[1], scaler.var_[1]).pdf(X[:,1])
sns.jointplot(p[:,0],p[:,1],kind='kde')

# %%
pval = np.zeros(X.shape)
pval[:,0] = stats.norm(scaler.mean_[0], scaler.var_[0]).pdf(Xval[:,0])
pval[:,1] = stats.norm(scaler.mean_[1], scaler.var_[1]).pdf(Xval[:,1])
sns.jointplot(pval[:,0],pval[:,1],kind='kde')

# %%
def select_threshold(pval, yval):
    best_epsilon = 0
    best_f1 = 0
    f1 = 0
    
    step = (pval.max() - pval.min()) / 1000
    
    for epsilon in np.arange(pval.min(), pval.max(), step):
        preds = pval < epsilon
        
        tp = np.sum(np.logical_and(preds == 1, yval == 1)).astype(float)
        fp = np.sum(np.logical_and(preds == 1, yval == 0)).astype(float)
        fn = np.sum(np.logical_and(preds == 0, yval == 1)).astype(float)
        
        precision = tp / (tp + fp)
        recall = tp / (tp + fn)
        f1 = (2 * precision * recall) / (precision + recall)
        
        if f1 > best_f1:
            best_f1 = f1
            best_epsilon = epsilon
    
    return best_epsilon, best_f1

# %% [markdown]
# ## 用含标签的数据训练处最佳的阈值

# %%
epsilon, f1 = select_threshold(pval, yval)
epsilon, f1
# Out:
# (0.009566706005956842, 0.7142857142857143)

# %% [markdown]
# ## 在训练集上判断小于该阈值的为异常点

# %%
outliers = np.where(p < epsilon)
outliers
# Out:
# (array([300, 301, 301, 303, 303, 304, 306, 306], dtype=int64),
#  array([1, 0, 1, 0, 1, 0, 0, 1], dtype=int64))

# %%
fig, ax = plt.subplots()
ax.scatter(X[:,0], X[:,1])
ax.scatter(X[outliers[0],0], X[outliers[0],1], s=50, color='r', marker='o')
plt.show()

# %% [markdown]
# # 协同过滤

# %%
data = loadmat('data/ex8_movies.mat')
Y = data['Y']
R = data['R']
data.keys(), Y.shape, R.shape
# Out:
# (dict_keys(['__header__', '__version__', '__globals__', 'Y', 'R']),
#  (1682, 943),
#  (1682, 943))

# %%
Y[2, np.where(R[1,:] == 1)[0]].mean()
# Out:
# 0.7709923664122137

# %% [markdown]
# # 代价函数
# <img style="float: left;" src="../img/rcmd_cost.png">

# %%
def cost(params, Y, R, num_features):
    Y = np.matrix(Y)  # (1682, 943)
    R = np.matrix(R)  # (1682, 943)
    num_movies = Y.shape[0]
    num_users = Y.shape[1]
    
    # reshape the parameter array into parameter matrices
    X = np.matrix(np.reshape(params[:num_movies * num_features], (num_movies, num_features)))  # (1682, 10)
    Theta = np.matrix(np.reshape(params[num_movies * num_features:], (num_users, num_features)))  # (943, 10)
    
    # initializations
    J = 0
    
    # compute the cost
    error = np.multiply((X * Theta.T) - Y, R)  # (1682, 943)
    squared_error = np.power(error, 2)  # (1682, 943)
    J = (1. / 2) * np.sum(squared_error)
    
    return J

# %%
params_data = loadmat('data/ex8_movieParams.mat')
X = params_data['X']
Theta = params_data['Theta']
X.shape, Theta.shape
# Out:
# ((1682, 10), (943, 10))

# %%
users = 4
movies = 5
features = 3

X_sub = X[:movies, :features]
Theta_sub = Theta[:users, :features]
Y_sub = Y[:movies, :users]
R_sub = R[:movies, :users]

params = np.concatenate((np.ravel(X_sub), np.ravel(Theta_sub)))

cost(params, Y_sub, R_sub, features)
# Out:
# 22.224603725685675

# %%
def cost(params, Y, R, num_features):
    Y = np.matrix(Y)  # (1682, 943)
    R = np.matrix(R)  # (1682, 943)
    num_movies = Y.shape[0]
    num_users = Y.shape[1]
    
    # reshape the parameter array into parameter matrices
    X = np.matrix(np.reshape(params[:num_movies * num_features], (num_movies, num_features)))  # (1682, 10)
    Theta = np.matrix(np.reshape(params[num_movies * num_features:], (num_users, num_features)))  # (943, 10)
    
    # initializations
    J = 0
    X_grad = np.zeros(X.shape)  # (1682, 10)
    Theta_grad = np.zeros(Theta.shape)  # (943, 10)
    
    # compute the cost
    error = np.multiply((X * Theta.T) - Y, R)  # (1682, 943)
    squared_error = np.power(error, 2)  # (1682, 943)
    J = (1. / 2) * np.sum(squared_error)
    
    # calculate the gradients
    X_grad = error * Theta
    Theta_grad = error.T * X
    
    # unravel the gradient matrices into a single array
    grad = np.concatenate((np.ravel(X_grad), np.ravel(Theta_grad)))
    
    return J, grad

# %%
J, grad = cost(params, Y_sub, R_sub, features)
J, grad
# Out:
# (22.224603725685675,
#  array([ -2.52899165,   7.57570308,  -1.89979026,  -0.56819597,
#           3.35265031,  -0.52339845,  -0.83240713,   4.91163297,
#          -0.76677878,  -0.38358278,   2.26333698,  -0.35334048,
#          -0.80378006,   4.74271842,  -0.74040871, -10.5680202 ,
#           4.62776019,  -7.16004443,  -3.05099006,   1.16441367,
#          -3.47410789,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   0.        ]))

# %%
def cost(params, Y, R, num_features, learning_rate):
    Y = np.matrix(Y)  # (1682, 943)
    R = np.matrix(R)  # (1682, 943)
    num_movies = Y.shape[0]
    num_users = Y.shape[1]
    
    # reshape the parameter array into parameter matrices
    X = np.matrix(np.reshape(params[:num_movies * num_features], (num_movies, num_features)))  # (1682, 10)
    Theta = np.matrix(np.reshape(params[num_movies * num_features:], (num_users, num_features)))  # (943, 10)
    
    # initializations
    J = 0
    X_grad = np.zeros(X.shape)  # (1682, 10)
    Theta_grad = np.zeros(Theta.shape)  # (943, 10)
    
    # compute the cost
    error = np.multiply((X * Theta.T) - Y, R)  # (1682, 943)
    squared_error = np.power(error, 2)  # (1682, 943)
    J = (1. / 2) * np.sum(squared_error)
    
    # add the cost regularization
    J = J + ((learning_rate / 2) * np.sum(np.power(Theta, 2)))
    J = J + ((learning_rate / 2) * np.sum(np.power(X, 2)))
    
    # calculate the gradients with regularization
    X_grad = (error * Theta) + (learning_rate * X)
    Theta_grad = (error.T * X) + (learning_rate * Theta)
    
    # unravel the gradient matrices into a single array
    grad = np.concatenate((np.ravel(X_grad), np.ravel(Theta_grad)))
    
    return J, grad

# %%
J, grad = cost(params, Y_sub, R_sub, features, 1.5)
J, grad
# Out:
# (31.34405624427422,
#  array([ -0.95596339,   6.97535514,  -0.10861109,   0.60308088,
#           2.77421145,   0.25839822,   0.12985616,   4.0898522 ,
#          -0.89247334,   0.29684395,   1.06300933,   0.66738144,
#           0.60252677,   4.90185327,  -0.19747928, -10.13985478,
#           2.10136256,  -6.76563628,  -2.29347024,   0.48244098,
#          -2.99791422,  -0.64787484,  -0.71820673,   1.27006666,
#           1.09289758,  -0.40784086,   0.49026541]))

# %%
movie_idx = {}
f = open('data/movie_ids.txt',encoding= 'gbk')
for line in f:
    tokens = line.split(' ')
    tokens[-1] = tokens[-1][:-1]
    movie_idx[int(tokens[0]) - 1] = ' '.join(tokens[1:])

# %%
movie_idx[0]
# Out:
# 'Toy Story (1995)'

# %%
ratings = np.zeros((1682, 1))

ratings[0] = 4
ratings[6] = 3
ratings[11] = 5
ratings[53] = 4
ratings[63] = 5
ratings[65] = 3
ratings[68] = 5
ratings[97] = 2
ratings[182] = 4
ratings[225] = 5
ratings[354] = 5

print('Rated {0} with {1} stars.'.format(movie_idx[0], str(int(ratings[0]))))
print('Rated {0} with {1} stars.'.format(movie_idx[6], str(int(ratings[6]))))
print('Rated {0} with {1} stars.'.format(movie_idx[11], str(int(ratings[11]))))
print('Rated {0} with {1} stars.'.format(movie_idx[53], str(int(ratings[53]))))
print('Rated {0} with {1} stars.'.format(movie_idx[63], str(int(ratings[63]))))
print('Rated {0} with {1} stars.'.format(movie_idx[65], str(int(ratings[65]))))
print('Rated {0} with {1} stars.'.format(movie_idx[68], str(int(ratings[68]))))
print('Rated {0} with {1} stars.'.format(movie_idx[97], str(int(ratings[97]))))
print('Rated {0} with {1} stars.'.format(movie_idx[182], str(int(ratings[182]))))
print('Rated {0} with {1} stars.'.format(movie_idx[225], str(int(ratings[225]))))
print('Rated {0} with {1} stars.'.format(movie_idx[354], str(int(ratings[354]))))
# Out:
# Rated Toy Story (1995) with 4 stars.
# Rated Twelve Monkeys (1995) with 3 stars.
# Rated Usual Suspects, The (1995) with 5 stars.
# Rated Outbreak (1995) with 4 stars.
# Rated Shawshank Redemption, The (1994) with 5 stars.
# Rated While You Were Sleeping (1995) with 3 stars.
# Rated Forrest Gump (1994) with 5 stars.
# Rated Silence of the Lambs, The (1991) with 2 stars.
# Rated Alien (1979) with 4 stars.
# Rated Die Hard 2 (1990) with 5 stars.
# Rated Sphere (1998) with 5 stars.

# %%
R = data['R']
Y = data['Y']

Y = np.append(Y, ratings, axis=1)
R = np.append(R, ratings != 0, axis=1)

Y.shape, R.shape, ratings.shape
# Out:
# ((1682, 944), (1682, 944), (1682, 1))

# %%
movies = Y.shape[0]  # 1682
users = Y.shape[1]  # 944
features = 10
learning_rate = 10.

X = np.random.random(size=(movies, features))
Theta = np.random.random(size=(users, features))
params = np.concatenate((np.ravel(X), np.ravel(Theta)))

X.shape, Theta.shape, params.shape
# Out:
# ((1682, 10), (944, 10), (26260,))

# %%
Ymean = np.zeros((movies, 1))
Ynorm = np.zeros((movies, users))

for i in range(movies):
    idx = np.where(R[i,:] == 1)[0]
    Ymean[i] = Y[i,idx].mean()
    Ynorm[i,idx] = Y[i,idx] - Ymean[i]

Ynorm.mean()
# Out:
# 5.507036456515984e-19

# %%
from scipy.optimize import minimize

fmin = minimize(fun=cost, x0=params, args=(Ynorm, R, features, learning_rate), 
                method='CG', jac=True, options={'maxiter': 100})
fmin
# Out:
#      fun: 38957.08127326079
#      jac: array([ 0.01828979, -0.00369012,  0.02346367, ..., -0.00078687,
#        -0.00176901,  0.0017321 ])
#  message: 'Maximum number of iterations has been exceeded.'
#     nfev: 148
#      nit: 100
#     njev: 148
#   status: 1
#  success: False
#        x: array([-0.45824074, -0.09137088, -0.10504944, ..., -0.01444037,
#         0.05289715, -0.04599962])

# %%
X = np.matrix(np.reshape(fmin.x[:movies * features], (movies, features)))
Theta = np.matrix(np.reshape(fmin.x[movies * features:], (users, features)))

X.shape, Theta.shape
# Out:
# ((1682, 10), (944, 10))

# %%
predictions = X * Theta.T 
my_preds = predictions[:, -1] + Ymean
my_preds.shape
# Out:
# (1682, 1)

# %%
sorted_preds = np.sort(my_preds, axis=0)[::-1]
sorted_preds[:10]
# Out:
# matrix([[5.00002253],
#         [5.00001239],
#         [4.99999945],
#         [4.99999773],
#         [4.99999617],
#         [4.99999587],
#         [4.99999352],
#         [4.99999333],
#         [4.99998919],
#         [4.99998489]])

# %%
idx = np.argsort(my_preds, axis=0)[::-1]
idx
# Out:
# matrix([[1188],
#         [1292],
#         [1121],
#         ...,
#         [1625],
#         [1308],
#         [1653]], dtype=int64)

# %%
print("Top 10 movie predictions:")
for i in range(10):
    j = int(idx[i])
    print('Predicted rating of {0} for movie {1}.'.format(str(float(my_preds[j])), movie_idx[j]))
# Out:
# Top 10 movie predictions:
# Predicted rating of 5.000022534350475 for movie Prefontaine (1997).
# Predicted rating of 5.000012393748761 for movie Star Kid (1997).
# Predicted rating of 4.999999445757176 for movie They Made Me a Criminal (1939).
# Predicted rating of 4.999997733047862 for movie Saint of Fort Washington, The (1993).
# Predicted rating of 4.9999961728503015 for movie Aiqing wansui (1994).
# Predicted rating of 4.999995866891034 for movie Someone Else's America (1995).
# Predicted rating of 4.999993520231474 for movie Entertaining Angels: The Dorothy Day Story (1996).
# Predicted rating of 4.99999332990865 for movie Great Day in Harlem, A (1994).
# Predicted rating of 4.99998919104958 for movie Santa with Muscles (1996).
# Predicted rating of 4.999984890116869 for movie Marlene Dietrich: Shadow and Light (1996) .
