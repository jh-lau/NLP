# %%
from kashgari.corpus import ChineseDailyNerCorpus
from kashgari.tasks.labeling import BiLSTM_Model

import numpy as np

# %%
train_x, train_y = ChineseDailyNerCorpus.load_data('train')
test_x, test_y = ChineseDailyNerCorpus.load_data('test')
valid_x,valid_y = ChineseDailyNerCorpus.load_data('valid')

# %%
model = BiLSTM_Model()
model.fit(train_x, train_y, valid_x, valid_y, epochs=3)
# Out:
# WARNING:root:Sequence length will auto set at 95% of sequence length
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input (InputLayer)           [(None, 97)]              0
# _________________________________________________________________
# layer_embedding (Embedding)  (None, 97, 100)           350000
# _________________________________________________________________
# layer_blstm (Bidirectional)  (None, 97, 256)           234496
# _________________________________________________________________
# layer_dropout (Dropout)      (None, 97, 256)           0
# _________________________________________________________________
# layer_time_distributed (Time (None, 97, 8)             2056
# _________________________________________________________________
# activation_1 (Activation)    (None, 97, 8)             0
# ...
# Total params: 586,552
# Trainable params: 586,552
# ...

# %%
model.predict('所以我们只能从福建福州市借书了'.split())
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
from kashgari.embeddings import BERTEmbedding
from kashgari.tasks.labeling import BiGRU_Model
import kashgari

# %%
bert_weights_path = r"D:\Github\NLP\Projects\data\bert_pretrained_model\chinese_L-12_H-768_A-12"

# %%
bert_embedding = BERTEmbedding(bert_weights_path, task='labeling', sequence_length=30)
# Out:
# WARNING:root:seq_len: 30

# %%
model = BiGRU_Model(bert_embedding)

# %%
model.fit(train_x, train_y)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# Input-Token (InputLayer)        [(None, 30)]         0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      [(None, 30)]         0
# __________________________________________________________________________________________________
# Embedding-Token (TokenEmbedding [(None, 30, 768), (2 16226304    Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, 30, 768)      1536        Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, 30, 768)      0           Embedding-Token[0][0]
# ...
