# %%
import matplotlib
print(matplotlib.__version__)
print(matplotlib.get_backend())
# Out:
# 3.0.3
# module://ipympl.backend_nbagg

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(facecolor='r')
ax = fig.add_subplot(111)
ax.set(
    xlim=[.5, 4.5], ylim = [-2, 8],
    title = 'Example',
    ylabel ='Y-Axis', xlabel='X-Axis'
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [(-2, 8),
#  Text(0, 0.5, 'Y-Axis'),
#  (0.5, 4.5),
#  Text(0.5, 0, 'X-Axis'),
#  Text(0.5, 1.0, 'Example')]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3,4],[1,4,9,16])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = np.linspace(0,1, 100)
fig, ax= plt.subplots()
p1 = ax.plot(x, np.sin(x))[0]
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
p1.set_color('r')
plt.show()
p1.set_linestyle('--')

# %%
type(p1)
# Out:
# matplotlib.lines.Line2D

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter([1,2,3,4],[1,4,9,16],[100,200,300,400], 'b','o')
ax.plot([1,2,3,4],[1,4,9,16],'r')

plt.show()

# %%
# 不够灵活
plt.figure()
plt.scatter([1,2,3,4],[1,4,9,16],[100,200,300,400], 'y','o')
plt.plot([1,2,3,4],[1,4,9,16],'r')
plt.show()

# %%
# 面向单个子图对象，多个Axes
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_facecolor('w')
axes[0,0].set_title('Upper Left')
axes[0,1].set_title('Upper Right')
axes[1,0].set_title('Lower Left')
axes[1,1].set_title('Lower Right')
axes[0,0].set_facecolor('r')

for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])
    
x = np.linspace(-10, 10, 100)
axes[0,0].plot(x, np.sin(x))
axes[1,0].plot(x, np.cos(x))
axes[0,1].plot(x, np.exp(x))
axes[1,1].plot(x, 1/(1+np.exp(-x)))

plt.show()

# %%
fig, axes = plt.subplots(2,1)
x = np.linspace(-10,10,100)
y1,y2 = np.sin(x), np.cos(x)
names = ['Signal1', 'Signal2']

axes[0].plot(x, y1)
axes[1].scatter(x, y2)
for i , ax in enumerate(axes):
    ax.set_title(names[i])
plt.savefig('sin&cos')
plt.show()

# %%
x = np.linspace(0, 10, 100)
fig, axes = plt.subplots(1,3)

for i in range(1, 6):
    axes[0].plot(x, i*x)
    
for i, ls in enumerate(['-', '--', ':', '-.']):
    axes[1].plot(x, np.cos(x)+i, linestyle=ls)
    
for i, (ls, mk) in enumerate(zip(['', '-',':'], ['o', '^', 's'])):
    axes[2].plot(x, np.cos(x)+i*x, linestyle=ls, marker=mk, markevery=10)

# %%
fig, ax = plt.subplots(figsize=(10,10))
x = np.arange(0,10,.1)
y = np.sin(x)
ax.bar(x, y, width=.04, linewidth=.2)
ax.plot(x, y, 'r--', linewidth=2)
plt.show()

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 200)
y1 = np.sin(x)
y2 = np.cos(x)
ax.fill_between(x,y1,y2,color='grey')
ax.plot(x,y1,'b')
ax.plot(x,y2,'r')
plt.show()

# %%
data_obj = {'x':x, 'sin':np.sin(x), 'cos':np.cos(x)}
fig, ax = plt.subplots()
ax.fill_between('x', 'sin','cos',color='c', data=data_obj)
ax.plot('x','sin', color='blue',data=data_obj)
ax.plot('x','cos', color='red',data=data_obj)
plt.show()

# %%
np.random.seed(1)

# Generate data...
y_raw = np.random.randn(1000).cumsum() + 15
x_raw = np.linspace(0, 24, y_raw.size)

# Get averages of every 100 samples...
x_pos = x_raw.reshape(-1, 100).min(axis=1)
y_avg = y_raw.reshape(-1, 100).mean(axis=1)
y_err = y_raw.reshape(-1, 100).ptp(axis=1)

bar_width = x_pos[1] - x_pos[0]

# Make a made up future prediction with a fake confidence
x_pred = np.linspace(0, 30)
y_max_pred = y_avg[0] + y_err[0] + 2.3 * x_pred
y_min_pred = y_avg[0] - y_err[0] + 1.2 * x_pred

# Just so you don't have to guess at the colors...
barcolor, linecolor, fillcolor = 'wheat', 'salmon', 'lightblue'


fig, ax = plt.subplots()

ax.plot(x_raw, y_raw, color=linecolor)
ax.bar(x_pos, y_avg, width=bar_width, color=barcolor, 
       yerr=y_err, ecolor='gray', edgecolor='gray')
ax.fill_between(x_pred, y_min_pred, y_max_pred, 
                color=fillcolor)

ax.set(title='Future Projection of Attitudes', 
       ylabel='Snarkiness (snark units)', 
       xlabel='Minutes since class began')

# plt.savefig("bar_fill.png")

plt.show()

# %% [markdown]
# ## 绘图属性

# %% [markdown]
# ### 颜色
#
# ### 颜色名字
#
# - b: blue
# - g: green
# - r: red
# - c: cyan
# - m: magenta
# - y: yellow
# - k: black
# - w: white
#
# ### 十六进制
# ### RGB

# %% [markdown]
# ### 标记(Markers)
#
# marker     |  description  | marker    |  description    | marker   |  description  | marker    |  description
# :----------|:--------------|:----------|:----------------|:---------|:--------------|:----------|:--------------
# "."        |  point        | "+"       |  plus           | ","      |  pixel        | "x"       |  cross
# "o"        |  circle       | "D"       |  diamond        | "d"      |  thin_diamond |           |
# "8"        |  octagon      | "s"       |  square         | "p"      |  pentagon     | "\*"      |  star
# "&#124;"   |  vertical line| "\_"      | horizontal line |  "h"     |  hexagon1     | "H"       |  hexagon2
# 0          |  tickleft     | 4         |  caretleft      | "<"      | triangle_left | "3"       |  tri_left
# 1          |  tickright    | 5         |  caretright     | ">"      | triangle_right| "4"       |  tri_right
# 2          |  tickup       | 6         |  caretup        | "^"      | triangle_up   | "2"       |  tri_up
# 3          |  tickdown     | 7         |  caretdown      | "v"      | triangle_down | "1"       |  tri_down
# "None"     |  nothing      | `None`    |  default        | " "      |  nothing      | ""        |  nothing

# %% [markdown]
# ### 线条样式
#
# linestyle          | description
# -------------------|------------------------------
# '-'                | solid
# '--'               | dashed
# '-.'               | dashdot
# ':'                | dotted
# 'None'             | draw nothing
# ' '                | draw nothing
# ''                 | draw nothing

# %%
xs, ys = np.mgrid[:4, 9:0:-1]
markers = [".", "+", ",", "x", "o", "D", "d", "", "8", "s", "p", "*", "|", "_", "h", "H", 0, 4, "<", "3",
           1, 5, ">", "4", 2, 6, "^", "2", 3, 7, "v", "1", "None", None, " ", ""]
descripts = ["point", "plus", "pixel", "cross", "circle", "diamond", "thin diamond", "",
             "octagon", "square", "pentagon", "star", "vertical bar", "horizontal bar", "hexagon 1", "hexagon 2",
             "tick left", "caret left", "triangle left", "tri left", "tick right", "caret right", "triangle right", "tri right",
             "tick up", "caret up", "triangle up", "tri up", "tick down", "caret down", "triangle down", "tri down",
             "Nothing", "default", "Nothing", "Nothing"]
fig, ax = plt.subplots(1, 1, figsize=(7.5, 4))
for x, y, m, d in zip(xs.T.flat, ys.T.flat, markers, descripts):
    ax.scatter(x, y, marker=m, s=100)
    ax.text(x + 0.1, y - 0.1, d, size=14)
ax.set_axis_off()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig, ax = plt.subplots()
t = np.arange(0.0, 5.0, 0.2)
plt.plot(t, t, '-', t, t**2, '--', t, t**3, '-.', 
         t, -t, ':');

# %%
t = np.arange(0., 5., 0.2)

fig, ax = plt.subplots()
plt.plot(t, t, 'r--', t, t**2, 'bs', 
         t, t**3, 'g^');

# %%
fig, ax = plt.subplots()

ax.scatter([1, 2, 3, 4], [4, 3, 2, 1])
ax.set_title(r'$\sigma_i=15$', fontsize=20)
ax.set_xlabel('X')

ax.annotate("$x^3\sin(x)$", (2.0, 3.0), 
        xytext=(2.5, 3.5),
        arrowprops={"arrowstyle":"->", "color":"blue"},
        color="r")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 自定义matplotlib文件

# %%
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\Administrator\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
fig, ax = plt.subplots(figsize=(4,3))
ax.plot(x, np.sin(x), "r--", lw=2, label="sin(x)")
ax.plot(x, np.cos(x), color="b", linestyle="-.", 
        linewidth=2, label="cos(x)")
ax.plot(x, np.cos(x)*np.sin(x), "go-", ms=3, label="sin(x)cos(x)")

ax.set_xlabel("x values")
ax.set_ylabel("y values")


# l1 = ax.legend(bbox_to_anchor=(1.04,1), borderaxespad=0)
# l2 = ax.legend(bbox_to_anchor=(1.04,0), loc="lower left", borderaxespad=0)
# l3 = ax.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
l4 = ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                mode="expand", borderaxespad=0, ncol=3)
# l5 = ax.legend(bbox_to_anchor=(1,0), loc="lower right", 
#                 bbox_transform=fig.transFigure, ncol=3)
# l6 = ax.legend(bbox_to_anchor=(0.4,0.8), loc="upper right")
plt.tight_layout()

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "r--", lw=2, label="sin(x)")
ax.plot(x, np.cos(x), color="b", linestyle="-.", 
        linewidth=2, label="cos(x)")

ax.set_title("axis labels and tile", fontsize=18, 
             fontname="serif", color="red")

ax.set_xlim([-2*np.pi, 2*np.pi*1.5])
ax.set_ylim([-0.9, 1.1])

ax.legend(loc="center right")
plt.show()

# %%
import matplotlib as mpl
x = np.linspace(-2*np.pi, 2*np.pi, 100)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "r--", lw=2, label="sin(x)")
ax.plot(x, np.cos(x), color="b", linestyle="-.", 
        linewidth=2, label="cos(x)")

# set major tick
ax.set_xticks([-2 * np.pi, -np.pi, 0, np.pi, 2 * np.pi])
ax.set_xticklabels(['$-2\pi$', '$-\pi$', 0, r'$\pi$', r'$2\pi$'])

# set minor tick
mpl.ticker.FixedLocator([-3 * np.pi / 2, -np.pi/2, 0,
                         np.pi/2, 3 * np.pi/2])

# ax.grid(ls=":")

ax.spines['right'].set_position(("data", 0))
ax.spines['top'].set_position(("data", 0))

ax.spines["bottom"].set_position(("data", 0))
ax.spines["left"].set_position(("data", 0))

# ax.set_xticks([])
# ax.set_yticks([])

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), "r--", lw=2, label="sin(x)")
ax.plot(x, np.cos(x), color="b", linestyle="-.", 
        linewidth=2, label="cos(x)")


ax.plot(0.78539816, 0.70710678, "yo", ms=10)

ax.text(-3.5, 0.75, "Hello World", fontsize=14, family="serif")
ax.annotate("sin(x)=cos(x)",
            fontsize=14, family="serif",
            xy=(0.78539816, 0.70710678),
            xytext=(2.0, 0.25),
            arrowprops=dict(arrowstyle="->"))


ax.set_title("axis labels and tile", fontsize=14, 
             fontname="serif", color="red")

ax.set_xlim([-2*np.pi, 2*np.pi*1.5])
ax.set_ylim([-0.9, 1.1])
# Out:
# (-0.9, 1.1)

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
fig, ax = plt.subplots()

ax.plot(x, np.cos(x)*np.sin(x), "bo-", ms=3, label="sin(x)cos(x)")
for label in ax.get_yticklabels():
    label.set_color("blue")
ax.set_xlabel("x values")
ax.set_ylabel("y1 values", color="blue")

ax2 = ax.twinx()
p2, = ax2.plot(x, x**2, "r")
for label in ax2.get_yticklabels():
    label.set_color("red")
ax2.set_ylabel("y2 value", color=p2.get_color())

ax2.spines["right"].set_color(p2.get_color())

ax2.tick_params(axis='y', colors=p2.get_color())
ax.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8, 4))

def f(x):
    return 1/(1 + x**2) + 0.1/(1 + ((3 - x)/0.1)**2)

def plot_and_format_axes(ax, x, f, fontsize):
    ax.plot(x, f(x), linewidth=2)
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(5))
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
    ax.set_xlabel(r"$x$", fontsize=fontsize)
    ax.set_ylabel(r"$f(x)$", fontsize=fontsize)
    
# main graph
ax = fig.add_axes([0.1, 0.15, 0.8, 0.8])
x = np.linspace(-4, 14, 1000)
plot_and_format_axes(ax, x, f, 18)

# inset
x0, x1 = 2.5, 3.5
ax.axvline(x0, ymax=0.3, color="grey", linestyle=":")
ax.axvline(x1, ymax=0.3, color="grey", linestyle=":")

ax = fig.add_axes([0.5, 0.5, 0.38, 0.42])
x = np.linspace(x0, x1, 1000)
plot_and_format_axes(ax, x, f, 14)

# %% [markdown]
# ### 3D绘图

# %%
from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection="3d")

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes(projection="3d")

z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)
ax.plot3D(x_line, y_line, z_line, 'gray')

z_points = 15 * np.random.random(100)
x_points = np.cos(z_points) + 0.1 * np.random.randn(100)
y_points = np.sin(z_points) + 0.1 * np.random.randn(100)
ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='jet');

# %%
def z_function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = z_function(X, Y)

fig = plt.figure()
ax = plt.axes(projection="3d")
p0 = ax.contour3D(X, Y, Z, 50, cmap='jet')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
fig.colorbar(p0)
plt.show()

# %%
def z_function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = z_function(X, Y)

fig, ax = plt.subplots()
p0 = ax.contour(X, Y, Z, levels=3, cmap='jet')
plt.clabel(p0, inline=True, 
          fontsize=10)
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
def z_function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = z_function(X, Y)

fig, ax = plt.subplots()
p0 = ax.contourf(X, Y, Z, cmap="jet")
ax.set_xlabel('x')
ax.set_ylabel('y')
fig.colorbar(p0)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

num_bars = 15
import random
x_pos = random.sample(range(20), num_bars)
y_pos = random.sample(range(20), num_bars)
z_pos = [0] * num_bars
x_size = np.ones(num_bars)
y_size = np.ones(num_bars)
z_size = random.sample(range(20), num_bars)

ax.bar3d(x_pos, y_pos, z_pos, x_size, y_size, z_size, color='red')
plt.show()

# %% [markdown]
# ### 动画

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")
ax.set_axis_off()
[x, t] = np.meshgrid(np.array(range(25))/24.0, 
                     np.arange(0, 575.5, 0.5)/575*17*np.pi-2*np.pi)
p = (np.pi/2)*np.exp(-t/(8*np.pi))
u = 1-(1-np.mod(3.6*t, 2*np.pi)/np.pi)**4/2
y = 2*(x**2-x)**2*np.sin(p)
r = u*(x*np.sin(p)+y*np.cos(p))

surf = ax.plot_surface(r*np.cos(t), r*np.sin(t), 
                       u*(x*np.cos(p)-y*np.sin(p)), 
                       rstride=1, cstride=1, cmap=cm.gist_rainbow_r,
linewidth=0, antialiased=True)
plt.show()

# %%
x = np.linspace(-2,2,1000)
y1 = np.sqrt(1-(abs(x)-1)**2)
y2 = -3*np.sqrt(1-(abs(x)/2)**0.5)
fig, ax = plt.subplots()
ax.fill_between(x, y1, color='red')
ax.fill_between(x, y2, color='red')

ax.set_xlim([-2.5, 2.5])
ax.text(0, -0.4, 'Scientific Python', fontsize=12, fontweight='bold',
           color='blue', horizontalalignment='center')
ax.axis('equal')
ax.set_axis_off()
# ax.set_xticks([])
# ax.set_yticks([])

# ax.spines['right'].set_color("white")
# ax.spines['top'].set_color("white")

# ax.spines["bottom"].set_color("white")
# ax.spines["left"].set_color("white")

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Collecting tensorflow==2.0.0-alpha0
#   Downloading http://mirrors.aliyun.com/pypi/packages/c7/90/cf5e7fbf4a3c14b314e1ed6571eae1f9ad3b5e32a4e24b2b817466435a21/tensorflow-2.0.0a0-cp37-cp37m-win_amd64.whl (49.4MB)
# Collecting google-pasta>=0.1.2 (from tensorflow==2.0.0-alpha0)
#   Downloading http://mirrors.aliyun.com/pypi/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (1.21.1)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (1.16.2)
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow==2.0.0-alpha0)
#   Downloading http://mirrors.aliyun.com/pypi/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl (411kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (0.8.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (0.33.1)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (1.1.0)
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow==2.0.0-alpha0)
#   Downloading http://mirrors.aliyun.com/pypi/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl (3.0MB)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (1.0.8)
# Requirement already satisfied: gast>=0.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: setuptools in c:\users\administrator\anaconda3\lib\site-packages (from protobuf>=3.6.1->tensorflow==2.0.0-alpha0) (40.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\administrator\anaconda3\lib\site-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0-alpha0) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\administrator\anaconda3\lib\site-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow==2.0.0-alpha0) (0.14.1)
# Requirement already satisfied: h5py in c:\users\administrator\anaconda3\lib\site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-alpha0) (2.9.0)
# Installing collected packages: google-pasta, tf-estimator-nightly, tb-nightly, tensorflow
#   Found existing installation: tensorflow 1.13.1
#     Uninstalling tensorflow-1.13.1:
#       Successfully uninstalled tensorflow-1.13.1
# Successfully installed google-pasta-0.1.7 tb-nightly-1.14.0a20190301 tensorflow-2.0.0a0 tf-estimator-nightly-1.14.0.dev2019030115

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0-alpha0'
