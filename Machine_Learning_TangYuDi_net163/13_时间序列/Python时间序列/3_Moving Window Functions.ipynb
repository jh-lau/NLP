# %%
# %matplotlib inline 
import matplotlib.pylab
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
df = pd.Series(np.random.randn(600), index = pd.date_range('7/1/2016', freq = 'D', periods = 600))
df.head()
# Out:
# 2016-07-01    0.131895
# 2016-07-02    0.921665
# 2016-07-03   -0.498185
# 2016-07-04    1.063823
# 2016-07-05    1.426022
# Freq: D, dtype: float64

# %%
r = df.rolling(window = 10)
r.mean().head(20)
# Out:
# 2016-07-01         NaN
# 2016-07-02         NaN
# 2016-07-03         NaN
# 2016-07-04         NaN
# 2016-07-05         NaN
# 2016-07-06         NaN
# 2016-07-07         NaN
# 2016-07-08         NaN
# 2016-07-09         NaN
# 2016-07-10    0.282912
# 2016-07-11    0.403041
# 2016-07-12    0.335377
# 2016-07-13    0.449664
# 2016-07-14    0.443155
# 2016-07-15    0.259557
# 2016-07-16    0.211914
# 2016-07-17    0.085678
# 2016-07-18    0.201604
# 2016-07-19   -0.029388
# 2016-07-20    0.004538
# Freq: D, dtype: float64

# %%
plt.figure(figsize=(15, 5))
df.plot(style='r--')
df.rolling(window=20).mean().plot(style='bo')
plt.show()
