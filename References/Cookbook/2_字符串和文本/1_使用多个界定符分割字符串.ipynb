# %%
import re

# %%
line = 'asdf fjdk; afed, fjek,asdf, foo'

# %%
line.split()
# Out:
# ['asdf', 'fjdk;', 'afed,', 'fjek,asdf,', 'foo']

# %%
re.split(r'[;,\s]\s*', line)
# Out:
# ['asdf', 'fjdk', 'afed', 'fjek', 'asdf', 'foo']

# %%
re.findall(r'\w+', line)
# Out:
# ['asdf', 'fjdk', 'afed', 'fjek', 'asdf', 'foo']
